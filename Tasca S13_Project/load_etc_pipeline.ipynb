# %% [markdown]
# # **<span style="color:#48B3AF; font-family: 'Courier New"> LOAD </span>**

# %% [markdown]
# ## **<span style="color:#476EAE; font-family: 'Courier New"> Resources </span>**

# %%
# Infrastructure
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
# Locations
os.makedirs("reporting", exist_ok=True)

# %%
# Import files for loading
dc_dci_coverage = pd.read_csv("loading/dc_dci_coverage.csv", dtype=str)
df_full = pd.read_csv("loading/df_full.csv", dtype=str)
