# %% [markdown]
# # **<span style="color:#48B3AF; font-family: 'Courier New"> LOAD </span>**

# %% [markdown]
# ## **<span style="color:#476EAE; font-family: 'Courier New"> Resources </span>**

# %%
# Infrastructure
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np

# %% [markdown]
# ### **<span style="color:#A7E399; font-family: 'Courier New"> Republic of Moldova </span>**

# %% [markdown]
# There are several resourses which include necessary information:
# #### URL: https://cnam.md/prestatori/informatii-pentru-farmacisti/lista-dc-a-medicamentelor-compensate-pentru-farmacii/?dir=8083
# - 3-Lista_DC_CNAM-04.02.2026.xls
# #### URL: https://cnam.md/prestatori/informatii-pentru-medici/lista-de-denumiri-comune-internationale-de-medicamente-compensate-din-faoam/?hilite=Anexa-1-la-ordin-ro_decembrie
# - Anexa-1-la-ordin-ro_decembrie-23.12.25.xlsx
# #### URL: https://cnam.md/beneficiari/medicamente-compensate-as/lista-medicamentelor-compensate/
# - Medicamente-compensate_beneficiari_Ro_02.03.2026.xlsx

# %% [markdown]
# ### **<span style="color:#A7E399; font-family: 'Courier New"> Spain </span>**
